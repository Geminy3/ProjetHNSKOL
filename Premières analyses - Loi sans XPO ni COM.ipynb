# %%
import pandas as pd
from wordcloud import WordCloud
import re
import nltk
import matplotlib.pyplot as plt
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy
import math
import stanza

# %matplotlib inline

# %%
df = pd.read_excel("./Exports/final_export.xlsx")

import matplotlib.pyplot as plt
# %matplotlib inline

group_year = df

group_year["preprocessed_xpo"] = group_year.preprocessed_xpo.isna()
group_year["preprocessed_xpo"][group_year.preprocessed_xpo == False] = "XPO ou Communiqué"
group_year["preprocessed_xpo"][group_year.preprocessed_xpo == True] = "Pas de documents"

group_year = group_year.groupby('year').preprocessed_xpo.value_counts().sort_index()
group_year = group_year.unstack()
group_year.plot.barh(grid=True, title="Présence ou non d'exposé des motifs ou de communiqué de presse par an")
print(group_year)
# Out:
# <ipython-input-3-feb503554226>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_year["preprocessed_xpo"][group_year.preprocessed_xpo == False] = "XPO ou Communiqué"
# preprocessed_xpo  Pas de documents  XPO ou Communiqué
# year
# 2007                             1                 19
# 2008                            16                 37
# 2009                             7                 34
# 2010                            23                 40
# 2011                            24                 35
# 2012                            20                 22
# 2013                            20                 44
# 2014                            25                 35
# 2015                            21                 46
# 2016                            32                 33
# 2017                            11                 25
# 2018                            18                 27
# 2019                            23                 26
# 2020                            16                 31
# 2021                            16                 18

# %% [markdown]
# ## Quelles lois n'ont pas d'exposé des motifs ?

# %%
df = pd.read_excel("./Exports/final_export.xlsx")
SXpo = df[["preprocessed_xpo", "titre"]]
SXpo = SXpo.loc[SXpo.preprocessed_xpo.isna()]
for item in SXpo.titre:
    SXpo.titre.loc[SXpo.titre == item] = re.sub("LOI", "", item)
    item = re.sub("LOI", "", item)
    SXpo.titre.loc[SXpo.titre == item] = re.sub("n°", "", item)
    item = re.sub("n°", "", item)
    SXpo.titre.loc[SXpo.titre == item] = re.sub("\d", "", item)
    item = re.sub("\d", "", item)
    SXpo.titre.loc[SXpo.titre == item] = re.sub("janvier|février|mars|avril|mai|juin|juillet|août|septembre|octobre|novembre|décembre", "", item)
    item = re.sub("janvier|février|mars|avril|mai|juin|juillet|août|septembre|octobre|novembre|décembre", "", item)
    SXpo.titre.loc[SXpo.titre == item] = re.sub("- du", "", item)
    item = re.sub("- du", "", item)
#    SXpo.titre.loc[SXpo.titre == item] = re.sub("organique -", "", item)
#    item = re.sub("organique", "", item)
    
SXpo
# Out:
#     preprocessed_xpo                                              titre
# 0                NaN        relative aux mesures conservatoires en m...
# 3                NaN        visant à sécuriser les droits à protecti...
# 5                NaN        portant simplification de dispositions d...
# 14               NaN        d'expérimentation territoriale visant à ...
# 15               NaN        pour le développement de l'alternance et...
# ..               ...                                                ...
# 733              NaN        encadrant les conditions de la vente à d...
# 736              NaN        relative à l'équipement numérique des ét...
# 737              NaN        visant à moderniser les outils et la gou...
# 739              NaN   organique      portant diverses dispositions ...
# 740              NaN   organique      relative à la nomination du pr...
#
# [273 rows x 2 columns]

# %%
title = [titre[1] for titre in SXpo.titre.items()]
title
# Out:
# ["      relative aux mesures conservatoires en matière de procédures de sauvegarde, de redressement judiciaire ou de liquidation judiciaire et aux biens qui en font l'objet",
#  '      visant à sécuriser les droits à protection sociale des assistants maternels et des salariés des particuliers employeurs',
#  '      portant simplification de dispositions du code électoral et relative à la transparence financière de la vie politique',
#  "      d'expérimentation territoriale visant à résorber le chômage de longue durée",
#  "      pour le développement de l'alternance et la sécurisation des parcours professionnels",
#  '      visant à reconnaître le vote blanc aux élections',
#  '      relative à la gouvernance de la sécurité sociale et à la mutualité',
#  "      relative à l'élection des conseillers municipaux dans les communes associées de la Polynésie française et à la modernisation du code général des collectivités territoriales applicable aux communes de la Polynésie française, à leurs groupements et à leurs établissements publics",
#  "      modifiant certaines dispositions issues de la loi      relative aux droits et à la protection des personnes faisant l'objet de soins psychiatriques et aux modalités de leur prise en charge",
#  "      relative à l'engagement des sapeurs-pompiers volontaires et à son cadre juridique",
#  "      relative au statut des témoins devant les commissions d'enquête parlementaires",
#  "   er   visant à préserver l'éthique du sport, à renforcer la régulation et la transparence du sport professionnel et à améliorer la compétitivité des clubs",
#  "   er   permettant la création de sociétés d'économie mixte à opération unique",
#  "      permettant le don de jours de repos à un parent d'un enfant gravement malade",
#  "      relative aux certificats d'obtention végétale",
#  '      de finances pour ',
#  '      relative à la mise en œuvre du transfert des compétences eau et assainissement aux communautés de communes',
#  "      autorisant l'accord local de répartition des sièges de conseiller communautaire",
#  "      visant à créer une allocation journalière d'accompagnement d'une personne en fin de vie",
#  '      tendant à créer un droit voisin au profit des agences de presse et des éditeurs de presse',
#  '      relative au suivi des enfants en danger par la transmission des informations',
#  "   er   rénovant les modalités d'inscription sur les listes électorales",
#  '      relative aux formations supplétives des forces armées',
#  '      visant à autoriser la restitution par la France des têtes maories à la Nouvelle-Zélande et relative à la gestion des collections',
#  '      réaffirmant le principe du repos dominical et visant à adapter les dérogations à ce principe dans les communes et zones touristiques et thermales ainsi que dans certaines grandes agglomérations pour les salariés volontaires',
#  '      visant à renforcer la lutte contre le système prostitutionnel et à accompagner les personnes prostituées',
#  "      visant à lutter contre l'absentéisme scolaire",
#  "      relative à l'établissement d'un contrôle des armes moderne, simplifié et préventif",
#  "      relative aux modalités de mise en œuvre des conventions conclues entre les organismes d'assurance maladie complémentaire et les professionnels, établissements et services de santé",
#  '      relative à la protection du secret des affaires',
#  '      relative au deuxième dividende numérique et à la poursuite de la modernisation de la télévision numérique terrestre',
#  '      portant dématérialisation du Journal officiel de la République française',
#  "      autorisant l'expérimentation des sons de naissance",
#  "      facilitant l'égal accès des femmes et des hommes au mandat de conseiller général",
#  "      encadrant la profession d'agent sportif",
#  "      renforçant l'information des voyageurs lors de la commercialisation de titres de transport sur les compagnies aériennes figurant sur la liste noire de l'Union européenne",
#  "Loi      tendant à modifier l'ordonnance      relative au fonctionnement des assemblées parlementaires et à compléter le code de justice administrative",
#  "      relative au devoir de vigilance des sociétés mères et des entreprises donneuses d'ordre",
#  "      relative à la lutte contre l'accaparement des terres agricoles et au développement du biocontrôle",
#  "      autorisant les petits consommateurs domestiques et non domestiques d'électricité et de gaz naturel à accéder ou à retourner au tarif réglementé",
#  '      portant réforme de la prescription en matière civile',
#  "      tendant au développement, à l'encadrement des stages et à l'amélioration du statut des stagiaires",
#  "      relative à l'exercice des compétences des collectivités territoriales dans le done de la gestion des milieux aquatiques et de la prévention des inondations",
#  "      visant à sécuriser l'exercice des praticiens diplômés hors Union européenne",
#  '      relative à la régulation du système de distribution de la presse',
#  '      relative à la suppression de la publicité commerciale dans les programmes jeunesse de la télévision publique',
#  "      rénovant la gouvernance des services publics d'eau potable et d'assainissement en Guadeloupe",
#  "      visant à faciliter la sortie de l'indivision successorale et à relancer la politique du logement en outre-mer",
#  '      relative aux violences faites spécifiquement aux femmes, aux violences au sein des couples et aux incidences de ces dernières sur les enfants',
#  "      visant à pénaliser l'acceptation par un parti politique d'un financement par une personne morale",
#  "      visant à renforcer la prise en charge des cancers pédiatriques par la recherche, le soutien aux aidants familiaux, la formation des professionnels et le droit à l'oubli",
#  "      permettant la recherche des bénéficiaires des contrats d'assurance sur la vie non réclamés et garantissant les droits des assurés",
#  '      relative à la lutte contre la fracture numérique',
#  '      de modernisation de diverses règles applicables aux élections',
#  '      visant à clarifier diverses dispositions du droit électoral',
#  "      portant création d'une première année commune aux études de santé et facilitant la réorientation des étudiants",
#  "      relative à l'instauration du   comme journée nationale de la Résistance",
#  '       portant réforme de la biologie médicale',
#  "      portant dispositions particulières relatives aux quartiers d'habitat informel et à la lutte contre l'habitat indigne dans les départements et régions d'outre-mer",
#  "      relative à l'interdiction des violences éducatives ordinaires",
#  "      visant à interdire l'exploration et l'exploitation des mines d'hydrocarbures liquides ou gazeux par fracturation hydraulique et à abroger les permis exclusifs de recherches comportant des projets ayant recours à cette technique",
#  '      tendant à garantir le droit au respect de la dignité en détention',
#  "      relative à l'organisation de la médecine du travail",
#  "      prorogeant le mandat des conseillers à l'Assemblée des Français de l'étranger",
#  "      visant à la suspension de la fabrication, de l'importation, de l'exportation et de la mise sur le marché de tout conditionnement à vocation alimentaire contenant du bisphénol A",
#  '      renforçant la lutte contre les rodéos motorisés',
#  "      tendant à sécuriser l'actionnariat des entreprises publiques locales",
#  '      renforçant le dialogue avec les supporters et la lutte contre le hooliganisme',
#  '      relative à la journée de solidarité',
#  "      relative aux comptes bancaires inactifs et aux contrats d'assurance vie en déshérence",
#  "      relative à la représentation équilibrée des femmes et des hommes au sein des conseils d'administration et de surveillance et à l'égalité professionnelle",
#  " organique      relative à la lutte contre la manipulation de l'information",
#  '      pour le développement des sociétés publiques locales',
#  "      visant à améliorer les droits des travailleurs et l'accompagnement des familles après le décès d'un enfant",
#  '      visant à encadrer le démarchage téléphonique et à lutter contre les appels frauduleux',
#  "Loi      pour l'amélioration et la simplification du droit de la chasse",
#  "      relative à la représentation des personnels administratifs, techniques et spécialisés au sein des conseils d'administration des services départementaux d'incendie et de secours \u200e(Loi n'appelant pas de décret d'application)\u200e",
#  " organique      relative à la nomination du directeur général de l'Agence nationale de la cohésion des territoires",
#  "   er  relative à l'organisation du championnat d'Europe de football de l'UEFA en ",
#  "      visant à reconquérir l'économie réelle",
#  '      relative aux recherches impliquant la personne hune',
#  '      relative au droit de résiliation sans frais de contrats de complémentaire santé',
#  "      relative à la solidarité dans les dones de l'alimentation en eau et de l'assainissement",
#  '      visant à définir et protéger le patrimoine sensoriel des campagnes françaises',
#  "      visant à encadrer l'exploitation commerciale de l'image d'enfants de moins de seize ans sur les plateformes en ligne",
#  '      portant diverses dispositions tendant à la modernisation du secteur de la presse',
#  "      pour l'économie bleue",
#  "Loi      relative aux tarifs réglementésd'électricité et de gaz naturel",
#  '      pour renforcer la prévention en santé au travail',
#  "      relative à la réforme des procédures de révision et de réexamen d'une condamnation pénale définitive",
#  "  -  du    relative aux conditions de commercialisation et d'utilisation de certains engins motorisés",
#  '      portant réforme de la prescription en matière pénale',
#  "      relative à l'amélioration du régime de la commune nouvelle, pour des communes fortes et vivantes",
#  "      relative à la simplification du droit et à l'allégement des démarches administratives",
#  "      relative à l'harmonisation de l'utilisation des caméras mobiles par les autorités de sécurité publique",
#  "      renforçant la lutte contre les violences de groupes et la protection des personnes chargées d'une mission de service public",
#  "      visant à garantir la qualité de l'offre alimentaire en outre-mer",
#  "      relative au renforcement de l'inclusion dans l'emploi par l'activité économique et à l'expérimentation « territoire zéro chômeur de longue durée »",
#  '      pour la protection foncière des activités agricoles et des cultures marines en zone littorale',
#  '      relative aux personnels enseignants de médecine générale',
#  "      relative à la reconnaissance du   comme journée nationale du souvenir et de recueillement à la mémoire des victimes civiles et militaires de la guerre d'Algérie et des combats en Tunisie et au Maroc",
#  '      visant à permettre aux conseillers de la métropole de Lyon de participer aux prochaines élections sénatoriales',
#  "      relative à la sécurité des manèges, machines et installations pour fêtes foraines ou parcs d'attractions",
#  "   er   relative au délai d'intervention du juge des libertés et de la détention en rétention administrative à Mayotte",
#  "      visant à faciliter l'exercice, par les élus locaux, de leur mandat",
#  "      portant création d'un Conseil national d'évaluation des normes applicables aux collectivités territoriales et à leurs établissements publics",
#  "      relative à l'indépendance de l'expertise en matière de santé et d'environnement et à la protection des lanceurs d'alerte",
#  "      relative à l'interdiction de la mise en culture des variétés de maïs génétiquement modifié",
#  '      visant à favoriser la reconnaissance des proches aidants',
#  "   er   visant à renforcer l'éthique du sport et les droits des sportifs",
#  "      tendant à améliorer la lisibilité du droit par l'abrogation de lois obsolètes",
#  '      relative aux sapeurs-pompiers professionnels et aux sapeurs-pompiers volontaires',
#  '      relative à la protection patrimoniale des langues régionales et à leur promotion',
#  "      tendant à modifier la loi      relative à la bioéthique en autorisant sous certaines conditions la recherche sur l'embryon et les cellules souches embryonnaires",
#  "      précisant les modalités de création d'une installation de stockage réversible en couche géologique profonde des déchets radioactifs de haute et moyenne activité à vie longue",
#  "      relative aux missions de l'Etablissement national des produits agricoles et de la pêche maritime",
#  "      tendant à inscrire l'inceste commis sur les mineurs dans le code pénal et à améliorer la détection et la prise en charge des victimes d'actes incestueux",
#  "      visant à mieux encadrer l'utilisation des produits phytosanitaires sur le territoire national",
#  "      améliorant l'efficacité de la justice de proximité et de la réponse pénale",
#  "      visant à rendre obligatoire l'installation de détecteurs de fumée dans tous les lieux d'habitation",
#  '      tendant à permettre le recours au vote par voie électronique lors des élections des membres de conseils des établissements publics à caractère scientifique, culturel et professionnel',
#  '      visant à assurer la revalorisation des pensions de retraite agricoles en France continentale et dans les outre-mer',
#  '      réformant le système de répression des abus de marché',
#  " organique      tendant à permettre à Saint-Barthélemy d'imposer les revenus de source locale des personnes établies depuis moins de cinq ans",
#  "      de simplification, de clarification et d'actualisation du droit des sociétés",
#  '      créant de nouveaux droits en faveur des malades et des personnes en fin de vie',
#  "      relative aux modalités de dépôt de candidature aux élections (Loi n'appelant pas de décret d'application)",
#  "      tendant à faciliter l'utilisation des réserves militaires et civiles en cas de crise majeure",
#  "   er   relative à l'exploitation numérique des livres indisponibles du XXe siècle",
#  '      visant à assouplir les règles relatives à la refonte de la carte intercommunale',
#  '      de libéralisation des ventes volontaires de meubles aux enchères publiques',
#  "      tendant à consolider et clarifier l'organisation de la manutention dans les ports maritimes",
#  "      portant création d'une Agence nationale de la cohésion des territoires",
#  "      relative à la transparence de l'information sur les produits agricoles et alimentaires",
#  "      visant à simplifier et mieux encadrer le régime d'ouverture et de contrôle des établissements privés hors contrat",
#  "      visant à protéger les mineurs des crimes et délits sexuels et de l'inceste",
#  '      pour une sécurité globale préservant les libertés',
#  '      visant à renforcer la coopération transfrontalière, transnationale et interrégionale par la mise en conformité du code général des collectivités territoriales avec le règlement communautaire relatif à un groupement européen de coopération territoriale',
#  "   er   relative aux modalités de calcul du potentiel fiscal agrégé des communautés d'agglomération issues de la transformation de syndicats d'agglomération nouvelle (ex SAN)",
#  "      relative à l'encadrement de l'utilisation du téléphone portable dans les établissements d'enseignement scolaire",
#  "      visant à renforcer la liberté, l'indépendance et le pluralisme des médias",
#  '   er   visant à améliorer la trésorerie des associations',
#  '      relative au prix du livre numérique',
#  ' organique      visant à clarifier diverses dispositions du droit électoral',
#  "   er   relative à l'exercice des professions de médecin, chirurgien-dentiste, pharmacien et sage-femme pour les professionnels titulaires d'un diplôme obtenu dans un Etat non membre de l'Union européenne",
#  "      visant à préparer la transition vers un système énergétique sobre et portant diverses dispositions sur la tarification de l'eau et sur les éoliennes",
#  "Loi   er   visant à prolonger l'application des articles ,  et  de la loi      relative à la lutte contre le terrorisme et portant dispositions diverses relatives à la sécurité et aux contrôles frontaliers",
#  "      portant diverses dispositions d'adaptation de la législation au droit de l'Union européenne",
#  "      relative à la sécurisation des transactions relatives à la zone d'aménagement concerté du quartier central de Gerland (Lyon)",
#  '      visant à lutter contre la concurrence sociale déloyale',
#  "      tendant à préciser l'infraction de violation de domicile",
#  '      modifiant la loi      créant le Conseil national des communes « Compagnon de la Libération »',
#  '      relative à la Polynésie française',
#  "      de simplification et d'amélioration de la qualité du droit",
#  "      relative au renforcement de la sécurité de l'usage des drones civils",
#  '      tendant à prolonger le délai de validité des habilitations des clercs de notaire',
#  '      tendant à renforcer les obligations comptables des partis politiques et des candidats',
#  '      renforçant la lutte contre la contrefaçon',
#  "      relative à la représentation communale dans les communautés de communes et d'agglomération",
#  "      modifiant certaines dispositions de la loi      portant réforme de l'hôpital et relative aux patients, à la santé et aux territoires",
#  '   er   relative aux taxis et aux voitures de transport avec chauffeur',
#  "      relative au droit des victimes de présenter une demande d'indemnité au Fonds de garantie des victimes des actes de terrorisme et d'autres infractions",
#  "      tendant à favoriser l'accès au crédit des petites et moyennes entreprises et à améliorer le fonctionnement des marchés financiers",
#  "       relative à la protection de l'identité",
#  "      visant à faciliter la mise en chantier des projets des collectivités locales d'Ile-de-France",
#  "      relative à la prorogation du mécanisme de l'éco-participation répercutée à l'identique et affichée pour les équipements électriques et électroniques ménagers",
#  '      relative à la délimitation des régions, aux élections régionales et départementales et modifiant le calendrier électoral',
#  "      permettant une bonne application du régime d'asile européen",
#  "      relative à la protection de l'enfant",
#  '      visant à agir contre les violences au sein de la famille',
#  " organique   er   rénovant les modalités d'inscription sur les listes électorales des Français établis hors de France",
#  "      relative à la lutte contre la manipulation de l'information",
#  '      visant à prolonger la durée de vie des agences pour la mise en valeur des espaces urbains de la zone dite des cinquante pas géométriques et à faciliter la reconstitution des titres de propriété en Guadeloupe, en Guyane, en Martinique, à La Réunion, à Mayotte et à Saint-Martin',
#  '      relative aux mesures de surveillance des communications électroniques internationales',
#  "      portant adaptation du deuxième cycle de l'enseignement supérieur français au système Licence-Master-Doctorat",
#  " organique      relative à la compétence du Défenseur des droits pour l'orientation et la protection des lanceurs d'alerte",
#  "     relative aux activités immobilières des établissements d'enseignement supérieur, aux structures interuniversitaires de coopération, et aux conditions de recrutement et d'emploi du personnel enseignant et universitaire",
#  "      relative à l'accueil des gens du voyage et à la lutte contre les installations illicites",
#  '      visant à améliorer le système de santé par la confiance et la simplification',
#  " organique   er   rénovant les modalités d'inscription sur les listes électorales des ressortissants d'un Etat membre de l'Union européenne autre que la France pour les élections municipales",
#  '      relative à la désignation aléatoire des comités de protection des personnes',
#  "Loi      de simplification et de clarification du droit et d'allègement des procédures",
#  "   er   tendant à prévenir les usages dangereux du protoxyde d'azote",
#  '      de finances rectificative pour ',
#  '      modifiant la loi      instituant un Contrôleur général des lieux de privation de liberté',
#  "   er   visant à adapter l'organisation des communes nouvelles à la diversité des territoires",
#  " organique      tendant à l'approbation d'accords entre l'Etat et les collectivités territoriales de Saint-Martin, de Saint-Barthélemy et de Polynésie française",
#  "      relative à la création des sons d'assistants maternels et portant diverses dispositions relatives aux assistants maternels",
#  '      relative à la création du Centre national de la musique',
#  '      modernisant le régime des sections de commune',
#  "      relative à l'extension du chèque emploi associatif",
#  ' organique      modifiant le livre III de la sixième partie du code général des collectivités territoriales relatif à Saint-Martin',
#  '      tendant à clarifier la procédure de signalement de situations de maltraitance par les professionnels de santé',
#  '      visant à la prise en compte des nouveaux indicateurs de richesse dans la définition des politiques publiques',
#  ' organique      relative à la nomination du directeur général de la société anonyme BPI-Groupe',
#  '      de programmation des finances publiques pour les \u200eannées  à \u200e',
#  "      tendant à faciliter l'organisation des manifestations sportives et culturelles",
#  "      créant un dispositif de don de jours de repos non pris au bénéfice des proches aidants de personnes en perte d'autonomie ou présentant un handicap",
#  '      relative aux délais de paiement des fournisseurs dans le secteur du livre',
#  '      harmonisant les taux de la taxe sur la valeur ajoutée applicables à la presse imprimée et à la presse en ligne',
#  "   er   en faveur de l'engagement associatif",
#  '      visant à lutter contre les contenus haineux sur internet',
#  '      visant à introduire une formation pratique aux gestes de premiers secours dans la préparation du permis de conduire',
#  "      portant déblocage exceptionnel de la participation et de l'intéressement",
#  '      visant à protéger les sportifs de haut niveau et professionnels et à sécuriser leur situation juridique et sociale',
#  "      permettant d'offrir des chèques-vacances aux personnels des secteurs sanitaire et médico-social en reconnaissance de leur action durant l'épidémie de covid-",
#  '      visant à lutter contre le mitage des espaces forestiers en Ile-de-France',
#  "      visant à créer le statut de citoyen sauveteur, lutter contre l'arrêt cardiaque et sensibiliser aux gestes qui sauvent",
#  "   er   relative à l'organisation des transports scolaires en Ile-de-France",
#  '      tendant à améliorer le fonctionnement des sons départementales des personnes handicapées et portant diverses dispositions relatives à la politique du handicap',
#  "      visant à améliorer l'accès à la prestation de compensation du handicap",
#  '      relative à la prévention et à la lutte contre les incivilités, contre les atteintes à la sécurité publique et contre les actes terroristes dans les transports collectifs de voyageurs',
#  '      relative à la déshérence des contrats de retraite supplémentaire',
#  '      visant à faciliter le stationnement des personnes en situation de handicap titulaires de la carte de stationnement',
#  '      visant à lutter contre la discrimination à raison de la précarité sociale',
#  ' organique      relative à la nomination des dirigeants de la SNCF',
#  '      relative à la régulation, à la responsabilisation et à la simplification dans le secteur du transport public particulier de personnes',
#  "      relative à l'organisation du service et à l'information des passagers dans les entreprises de transport aérien de passagers et à diverses dispositions dans le done des transports",
#  '      portant statut général des autorités administratives indépendantes et des autorités publiques indépendantes',
#  "      portant diverses dispositions d'ordre cynégétique",
#  '      fixant le nombre et la répartition des sièges de conseiller de Paris',
#  '      visant à garantir la présence des parlementaires dans certains organismes extérieurs au Parlement et à simplifier les modalités de leur nomination',
#  " organique      de modernisation des règles applicables à l'élection présidentielle",
#  '      visant à abroger la loi      relative à la majoration des droits à construire',
#  "      relative à la protection des forêts contre l'incendie",
#  "   er   relative à la procédure applicable devant le conseil de prud'hommes dans le cadre d'une prise d'acte de rupture du contrat de travail par le salarié",
#  " organique      relative à la nomination à la présidence du conseil d'administration de l'Agence française pour la biodiversité (Loi n'appelant pas de décret d'application)",
#  '      visant à instaurer un service citoyen pour les mineurs délinquants',
#  "      visant à améliorer la santé visuelle des personnes âgées en perte d'autonomie",
#  "      relative à la répartition des sièges de conseiller à l'Assemblée de Guyane entre les sections électorales",
#  "      visant à mettre en place un dispositif de réduction d'activité des moniteurs de ski ayant atteint l'âge d'ouverture du droit à une pension de retraite, afin de favoriser l'activité des nouveaux moniteurs",
#  "      tendant à abroger la loi      visant à lutter contre l'absentéisme scolaire",
#  '      visant à proroger le mandat du Médiateur de la République',
#  "      relative à la sobriété, à la transparence, à l'information et à la concertation en matière d'exposition aux ondes électromagnétiques",
#  "      tendant à permettre le ntien des communes associées, sous forme de communes déléguées, en cas de création d'une commune nouvelle (Loi n'appelant pas de décret d'application)",
#  "      visant à homologuer des peines d'emprisonnement prévues en Nouvelle-Calédonie",
#  "   er   visant à préserver les intérêts de la défense et de la sécurité nationale de la France dans le cadre de l'exploitation des réseaux radioélectriques mobiles",
#  "      relative à la réforme de la Caisse des Français de l'étranger",
#  "      tendant à renforcer les moyens du Parlement en matière de contrôle de l'action du Gouvernement et d'évaluation des politiques publiques",
#  "      visant à renforcer et garantir le ntien de l'ordre public lors des manifestations",
#  "Loi      relative à l'extension du chèque emploi associatif",
#  '      relative au service civique',
#  "      visant à répartir les responsabilités et les charges financières concernant les ouvrages d'art de rétablissement des voies",
#  ' organique      portant dématérialisation du Journal officiel de la République française',
#  "      relative à l'action extérieure des collectivités territoriales et à la coopération des outre-mer dans leur environnement régional",
#  "      facilitant le déploiement d'un réseau d'infrastructures de recharge de véhicules électriques sur l'espace public",
#  '      visant à faciliter la saisie et la confiscation en matière pénale',
#  "      modifiant le mode de scrutin de l'élection de l'Assemblée de Corse et certaines dispositions relatives au fonctionnement de la collectivité territoriale de Corse",
#  "      relative à l'exercice, par la Croix-Rouge française, de sa mission statutaire de rétablissement des liens familiaux",
#  "      visant à permettre l'application aux élus locaux des dispositions relatives au droit individuel à la formation et relative aux conditions d'exercice des mandats des membres des syndicats de communes et des syndicats mixtes",
#  '      tendant à suspendre la commercialisation de biberons produits à base de bisphénol A',
#  "      visant à favoriser l'assainissement cadastral et la résorption du désordre de propriété",
#  '      relative au défibrillateur cardiaque',
#  "      relative à l'extension du délit d'entrave à l'interruption volontaire de grossesse",
#  ' organique      relative au statut des autorités administratives indépendantes créées par la Nouvelle-Calédonie',
#  ' organique      relative aux autorités administratives indépendantes et autorités publiques indépendantes',
#  "      prorogeant jusqu'au    le régime social du bonus exceptionnel outre-mer",
#  "      visant à harmoniser les délais de prescription des infractions prévues par la loi sur la liberté de la presse du   , commises en raison du sexe, de l'orientation ou de l'identité sexuelle ou du handicap",
#  '      relative aux juridictions de proximité',
#  '      relative à la lutte contre le gaspillage alimentaire',
#  '      visant à protéger les victimes de violences conjugales',
#  "      instaurant des mesures de sûreté à l'encontre des auteurs d'infractions terroristes à l'issue de leur peine",
#  "      relative à l'exécution des décisions de justice, aux conditions d'exercice de certaines professions réglementées et aux experts judiciaires",
#  "   er   créant de nouveaux droits pour les victimes et améliorant l'exécution des peines",
#  '      visant à garantir de justes conditions de rémunération aux salariés concernés par une procédure de reclassement',
#  'Loi     relative à la législation funéraire',
#  "      relative à la réforme du courtage de l'assurance et du courtage en opérations de banque et en services de paiement",
#  '      relative au renforcement de la protection des installations civiles abritant des matières nucléaires',
#  "      encadrant les conditions de la vente à distance des livres et habilitant le Gouvernement à modifier par ordonnance les dispositions du code de la propriété intellectuelle relatives au contrat d'édition",
#  "      relative à l'équipement numérique des établissements de spectacles cinématographiques",
#  '      visant à moderniser les outils et la gouvernance de la Fondation du patrimoine',
#  ' organique      portant diverses dispositions relatives à la collectivité de Saint-Barthélemy',
#  ' organique      relative à la nomination du président de la Commission nationale de contrôle des techniques de renseignement']

# %%
def top_feats(row, features, top_n=25):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids if row[i]>0]
    df = pd.DataFrame(top_feats)
    if len(top_feats) > 0:
        df.columns = ['feature', 'score']
    return df

def top_feats_in_doc(Xtr, features, row_id, top_n=25):
    ''' Top features in specific document (matrix row) '''
    row = np.squeeze(Xtr[row_id].toarray())
    return top_feats(row, features, top_n)

# %%
import string

with open("./stopwords/Stop-words-french.txt", "r", encoding='utf8') as f:
    stopW1 = [line.rstrip("\n") for line in f.readlines()]
with open("./stopwords/stopword.txt", "r", encoding='utf8') as f:
    stopW2 = [line.rstrip("\n") for line in f.readlines()]
stopW = stopW1 + stopW2 #+ stopwords.words("french")
stopW.extend(string.punctuation)
stopW.extend(['’', '«', '»', '…', '—','».', '»,', '---', '.—', '…—', 'ans', 'an'])

# %%
tf_vectorizer = CountVectorizer(stop_words=stopW)
tf_vectorizer.fit(title)

X = tf_vectorizer.transform(title)
X = X.toarray()
features = tf_vectorizer.get_feature_names()

(num_doc, num_f) = X.shape

tf_sum = np.sum(X, axis=0)
tf = top_feats(tf_sum, features)
top_feats(tf_sum, features)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abord', 'ain', 'aren', 'assemblée', 'aujourd', 'bicaméralisme', 'bicamérisme', 'budgétaire', 'cavalier', 'confiance', 'conférence', 'conseil', 'constitutionnel', 'constitutionnelle', 'couldn', 'didn', 'doesn', 'don', 'doute', 'délégation', 'enquête', 'exposé', 'financement', 'finances', 'groupe', 'hadn', 'hasn', 'haven', 'hui', 'isn', 'jour', 'journal', 'll', 'mal', 'mdr', 'ministres', 'mixte', 'motifs', 'motion', 'nationale', 'officiel', 'ordre', 'organique', 'paritaire', 'parlementaire', 'politique', 'programme', 'proposition', 'président', 'présidents', 'publique', 'puisqu', 'question', 'ratification', 'shouldn', 'sociale', 'sommaire', 'séance', 'sécurite', 'temps', 'traités', 've', 'wasn', 'weren', 'won', 'wouldn', 'êetre'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
#            feature  score
# 0         relative    114
# 1           visant     71
# 2          tendant     26
# 3           contre     26
# 4          portant     22
# 5               er     21
# 6        organique     18
# 7            lutte     14
# 8       protection     13
# 9         diverses     12
# 10        communes     11
# 11       renforcer     10
# 12       améliorer     10
# 13       relatives     10
# 14           santé      9
# 15       française      8
# 16       publiques      8
# 17  établissements      8
# 18          lutter      8
# 19       faciliter      8
# 20   collectivités      8
# 21          france      8
# 22  simplification      8
# 23        création      8
# 24        sécurité      8

# %%
words = tf['feature'][0:5]
words = words.append(tf['feature'][6:7])
print(words)

for i in range(len(title)):
    for word in words:
        title[i] = re.sub(word, "", title[i])
    title[i] = re.sub(" er", "", title[i])
    title[i] = re.sub("modifiant", "", title[i])
#    title[i] = re.sub("relative", "", title[i])
#    title[i] = re.sub("mesure", "", title[i])
#    title[i] = re.sub("procédures", "", title[i])
#    title[i] = re.sub("dispositions", "", title[i])
#    title[i] = re.sub("visant", "", title[i])
#    title[i] = re.sub("objet", "", title[i])
#    title[i] = re.sub("tendant", "", title[i])
#    title[i] = re.sub("portant", "", title[i])
#    title[i] = re.sub("er", "", title[i])
# Out:
# 0     relative
# 1       visant
# 2      tendant
# 3       contre
# 4      portant
# 6    organique
# Name: feature, dtype: object

# %%
tf_vectorizer.fit(title)
X = tf_vectorizer.transform(title)
X = X.toarray()
features = tf_vectorizer.get_feature_names()

(num_doc, num_f) = X.shape

tf_sum = np.sum(X, axis=0)
tf = top_feats(tf_sum, features)
top_feats(tf_sum, features)
# Out:
#            feature  score
# 0            lutte     14
# 1       protection     13
# 2         diverses     12
# 3         communes     11
# 4        renforcer     10
# 5        améliorer     10
# 6            santé      9
# 7         création      8
# 8   simplification      8
# 9         sécurité      8
# 10   collectivités      8
# 11          lutter      8
# 12       faciliter      8
# 13       française      8
# 14         général      8
# 15       publiques      8
# 16  établissements      8
# 17          france      8
# 18         réforme      7
# 19     application      7
# 20   territoriales      7
# 21        exercice      7
# 22             vie      7
# 23      conditions      7
# 24    organisation      7

# %%
# les "labels" du nuage sont les mots
cloud_labels = features
# les poids correspondent à la somme des TF selon les lignes de la matrice
cloud_weights = tf_sum  #axis=0 ça veut dire qu'on prend les colonnes
# on construit un dictionnaire qui associe chaque label (mot) au poids correspondant (TF total)
dictionary = dict(zip(cloud_labels, cloud_weights)) # zip "colle" le vecteur des labels au vecteur des poids
# on trie par ordre décroissant
sorted_by_value = sorted(dictionary.items(), key=lambda kv: kv[1], reverse=True) #On dit qu'on trie à partir de la valeur située en 1 (donc le poids)

limit = 25
fontcolor='#fafafa'
bgcolor = '#000000'

wordcloud = WordCloud(
    max_words=limit,
    background_color=bgcolor,
).fit_words(dictionary)

fig = plt.figure()
fig.set_figwidth(14)
fig.set_figheight(18)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
titre = title
print(titre[1])
SXpo.reset_index(inplace=True, drop=False)
for i in range(len(titre)):
    titre[i] = nltk.tokenize.word_tokenize(titre[i])
    titre[i] = [word for word in titre[i] if word not in stopW]

    SXpo.titre[i] = titre[i]
#    SXpo.titre[i] = titre[i]
SXpo.titre.head()
# Out:
#        à sécuriser les droits à protection sociale des assistants maternels et des salariés des particuliers employeurs
# <ipython-input-12-ef3064f777fa>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SXpo.titre[i] = titre[i]
# 0    [mesures, conservatoires, procédures, sauvegar...
# 1    [sécuriser, protection, sociale, assistants, m...
# 2    [simplification, électoral, transparence, fina...
# 3    [d'expérimentation, territoriale, résorber, ch...
# 4    [développement, l'alternance, sécurisation, pa...
# Name: titre, dtype: object

# %%
SXpo.titre
# Out:
# 0      [mesures, conservatoires, procédures, sauvegar...
# 1      [sécuriser, protection, sociale, assistants, m...
# 2      [simplification, électoral, transparence, fina...
# 3      [d'expérimentation, territoriale, résorber, ch...
# 4      [développement, l'alternance, sécurisation, pa...
#                              ...
# 268    [encadrant, conditions, vente, distance, livre...
# 269    [l'équipement, numérique, établissements, spec...
# 270    [moderniser, outils, gouvernance, Fondation, p...
# 271           [diverses, collectivité, Saint-Barthélemy]
# 272    [nomination, président, Commission, nationale,...
# Name: titre, Length: 273, dtype: object

# %%
for i in range(len(titre)):
    temp = ""
    for word in titre[i]:
        temp = temp + " " + word
    SXpo.titre[i] = temp
print(SXpo.titre)
# Out:
# 0       mesures conservatoires procédures sauvegarde ...
# 1       sécuriser protection sociale assistants mater...
# 2       simplification électoral transparence financi...
# 3       d'expérimentation territoriale résorber chôma...
# 4       développement l'alternance sécurisation parco...
#                              ...
# 268     encadrant conditions vente distance livres ha...
# 269     l'équipement numérique établissements spectac...
# 270     moderniser outils gouvernance Fondation patri...
# 271               diverses collectivité Saint-Barthélemy
# 272     nomination président Commission nationale con...
# Name: titre, Length: 273, dtype: object
# <ipython-input-15-9c025a3c371f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SXpo.titre[i] = temp

# %% [markdown]
# ### On peut essayer de regarder combien de textes de lois se rapporte à chacun de ces mots

# %%
tf_vectorizer.fit(SXpo.titre)
X_hp = tf_vectorizer.transform(SXpo.titre)
features_hp = tf_vectorizer.get_feature_names()

SXpo['category'] = ["" for i in range(len(SXpo.titre))]

i = 0
for titre1 in SXpo.titre:
    cat = top_feats_in_doc(X_hp, features_hp, i, 1)
#    print(titre1, "&", cat.feature.item())
#    if cat.feature.item() in tf.feature.values:
#        print(cat.feature.item())
    SXpo['category'].loc[SXpo.titre == titre1] = cat.feature.item()
    i += 1
    
SXpo
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#      index preprocessed_xpo  \
# 0        0              NaN
# 1        3              NaN
# 2        5              NaN
# 3       14              NaN
# 4       15              NaN
# ..     ...              ...
# 268    733              NaN
# 269    736              NaN
# 270    737              NaN
# 271    739              NaN
# 272    740              NaN
#
#                                                  titre      category
# 0     mesures conservatoires procédures sauvegarde ...    judiciaire
# 1     sécuriser protection sociale assistants mater...     maternels
# 2     simplification électoral transparence financi...  transparence
# 3     d'expérimentation territoriale résorber chôma...  territoriale
# 4     développement l'alternance sécurisation parco...      parcours
# ..                                                 ...           ...
# 268   encadrant conditions vente distance livres ha...      modifier
# 269   l'équipement numérique établissements spectac...     numérique
# 270   moderniser outils gouvernance Fondation patri...    moderniser
# 271             diverses collectivité Saint-Barthélemy  collectivité
# 272   nomination président Commission nationale con...      contrôle
#
# [273 rows x 4 columns]

# %%
group_cat = SXpo.groupby('category').count().sort_index()

group_cat = group_cat.iloc[1:len(group_cat),1:3]

#print(group_cat)

g = group_cat.loc[group_cat.titre > 1].plot(kind="barh", grid=True, figsize=(10, 8))

# %% [markdown]
# ### On peut chercher à comprendre le contexte de chacun de ces mots, en particulier ceux qui peuvent se rapporter à des problématiques sécuritaires en regardant les co-occurences de mots

# %%
t_freq = np.where(cloud_weights>2)
#print(t_freq[0])
index = t_freq[0]
X_small = X[:,index]
features_small = np.array(features)[index]
print(X_small.shape)

(_,num_f_small) = X_small.shape

print("Nombre de colonnes = mots : " + str(num_f_small))
# Out:
# (273, 183)
# Nombre de colonnes = mots : 183

# %%
co_occ = np.matmul(X_small.transpose(), X_small)
for i in range(len(features_small)):
    id_mot = np.where(features_small == features_small[i])[0][0]
    scores_coocc = co_occ[id_mot,:]
    dico_co_occ = dict(zip(features_small, scores_coocc))
    mots_coocc = sorted(dico_co_occ.items(), key=lambda kv: kv[1], reverse=True)
    
    if mots_coocc[1][1] > 2:
#    if features_small[i] == "protection" or features_small[i] == "lutte" or features_small[i] == "sécurité":
        print("[{}] apparaît le plus avec {}".format(features_small[i], mots_coocc[1:4]))
# Out:
# [actes] apparaît le plus avec [('victimes', 3), ('améliorer', 1), ('charge', 1)]
# [administratives] apparaît le plus avec [('indépendantes', 5), ('administratives', 4), ('publiques', 2)]
# [agglomération] apparaît le plus avec [('communautés', 3), ('syndicats', 2), ('communes', 1)]
# [appelant] apparaît le plus avec [('application', 4), ('administration', 2), ('communes', 2)]
# [application] apparaît le plus avec [('appelant', 4), ('communes', 3), ('administration', 2)]
# [assainissement] apparaît le plus avec [('eau', 3), ('communautés', 1), ('communes', 1)]
# [assistants] apparaît le plus avec [('maternels', 5), ('création', 2), ('diverses', 2)]
# [autorités] apparaît le plus avec [('indépendantes', 9), ('administratives', 5), ('publiques', 4)]
# [barthélemy] apparaît le plus avec [('barthélemy', 3), ('collectivités', 1), ('diverses', 1)]
# [charge] apparaît le plus avec [('prise', 3), ('actes', 1), ('aidants', 1)]
# [collectivités] apparaît le plus avec [('territoriales', 7), ('coopération', 3), ('française', 3)]
# [communautés] apparaît le plus avec [('communautés', 3), ('communes', 2), ('assainissement', 1)]
# [commune] apparaît le plus avec [('communes', 3), ('création', 2), ('régime', 2)]
# [communes] apparaît le plus avec [('française', 4), ('polynésie', 4), ('application', 3)]
# [conseiller] apparaît le plus avec [('répartition', 3), ('sièges', 3), ('accès', 1)]
# [coopération] apparaît le plus avec [('collectivités', 3), ('territoriales', 3), ('général', 2)]
# [eau] apparaît le plus avec [('assainissement', 3), ('communautés', 1), ('communes', 1)]
# [européenne] apparaît le plus avec [('union', 5), ('exercice', 2), ('commercialisation', 1)]
# [france] apparaît le plus avec [('ile', 3), ('inscription', 2), ('listes', 2)]
# [française] apparaît le plus avec [('polynésie', 6), ('communes', 4), ('collectivités', 3)]
# [général] apparaît le plus avec [('collectivités', 3), ('territoriales', 3), ('autorités', 2)]
# [ile] apparaît le plus avec [('ile', 3), ('collectivités', 1), ('faciliter', 1)]
# [indépendantes] apparaît le plus avec [('indépendantes', 9), ('administratives', 5), ('publiques', 4)]
# [inscription] apparaît le plus avec [('listes', 3), ('rénovant', 3), ('électorales', 3)]
# [listes] apparaît le plus avec [('listes', 3), ('rénovant', 3), ('électorales', 3)]
# [lutte] apparaît le plus avec [('renforçant', 4), ('information', 2), ('sécurité', 2)]
# [martin] apparaît le plus avec [('martin', 3), ('collectivités', 2), ('territoriales', 2)]
# [maternels] apparaît le plus avec [('maternels', 5), ('création', 2), ('diverses', 2)]
# [mer] apparaît le plus avec [('outre', 6), ('action', 1), ('agricoles', 1)]
# [outre] apparaît le plus avec [('outre', 6), ('action', 1), ('agricoles', 1)]
# [polynésie] apparaît le plus avec [('polynésie', 6), ('communes', 4), ('collectivités', 3)]
# [pompiers] apparaît le plus avec [('sapeurs', 5), ('volontaires', 3), ('professionnels', 2)]
# [prise] apparaît le plus avec [('charge', 3), ('actes', 1), ('aidants', 1)]
# [publics] apparaît le plus avec [('établissements', 3), ('collectivités', 2), ('communes', 2)]
# [publiques] apparaît le plus avec [('autorités', 4), ('indépendantes', 4), ('administratives', 2)]
# [renforcer] apparaît le plus avec [('sport', 3), ('coopération', 2), ('politiques', 2)]
# [renforçant] apparaît le plus avec [('lutte', 4), ('commercialisation', 1), ('européenne', 1)]
# [rénovant] apparaît le plus avec [('inscription', 3), ('listes', 3), ('électorales', 3)]
# [répartition] apparaît le plus avec [('répartition', 3), ('sièges', 3), ('assemblée', 1)]
# [saint] apparaît le plus avec [('barthélemy', 4), ('martin', 4), ('collectivités', 3)]
# [sapeurs] apparaît le plus avec [('sapeurs', 5), ('volontaires', 3), ('professionnels', 2)]
# [sein] apparaît le plus avec [('violences', 3), ('administration', 2), ('conseils', 2)]
# [sièges] apparaît le plus avec [('répartition', 3), ('sièges', 3), ('assemblée', 1)]
# [sport] apparaît le plus avec [('renforcer', 3), ('améliorer', 2), ('régulation', 2)]
# [statut] apparaît le plus avec [('autorités', 3), ('indépendantes', 3), ('administratives', 2)]
# [territoriales] apparaît le plus avec [('territoriales', 7), ('coopération', 3), ('française', 3)]
# [union] apparaît le plus avec [('union', 5), ('exercice', 2), ('commercialisation', 1)]
# [victimes] apparaît le plus avec [('actes', 3), ('infractions', 2), ('améliorer', 1)]
# [violences] apparaît le plus avec [('sein', 3), ('enfants', 2), ('femmes', 2)]
# [volontaires] apparaît le plus avec [('pompiers', 3), ('sapeurs', 3), ('certaines', 1)]
# [électorales] apparaît le plus avec [('inscription', 3), ('listes', 3), ('rénovant', 3)]
# [établissements] apparaît le plus avec [('publics', 3), ('collectivités', 2), ('communes', 2)]

# %% [markdown]
# ## COLLOCATION

# %%
from nltk.tokenize import word_tokenize

words = [w.lower() for titre in SXpo.titre for w in word_tokenize(titre)]
print(words[0:100])
# Out:
# ['mesures', 'conservatoires', 'procédures', 'sauvegarde', 'redressement', 'judiciaire', 'liquidation', 'judiciaire', 'biens', "l'objet", 'sécuriser', 'protection', 'sociale', 'assistants', 'maternels', 'salariés', 'particuliers', 'employeurs', 'simplification', 'électoral', 'transparence', 'financière', 'vie', 'politique', "d'expérimentation", 'territoriale', 'résorber', 'chômage', 'longue', 'durée', 'développement', "l'alternance", 'sécurisation', 'parcours', 'professionnels', 'reconnaître', 'vote', 'blanc', 'gouvernance', 'sécurité', 'sociale', 'mutualité', "l'élection", 'conseillers', 'municipaux', 'communes', 'associées', 'polynésie', 'française', 'modernisation', 'général', 'collectivités', 'territoriales', 'applicable', 'communes', 'polynésie', 'française', 'groupements', 'établissements', 'publics', 'certaines', 'issues', 'protection', 'faisant', "l'objet", 'soins', 'psychiatriques', 'prise', 'charge', "l'engagement", 'sapeurs-pompiers', 'volontaires', 'juridique', 'statut', 'témoins', 'devant', 'commissions', "d'enquête", 'parlementaires', 'préserver', "l'éthique", 'sport', 'renforcer', 'régulation', 'transparence', 'sport', 'professionnel', 'améliorer', 'compétitivité', 'clubs', 'permettant', 'création', 'sociétés', "d'économie", 'mixte', 'opération', 'unique', 'permettant', 'don', 'jours']

# %%
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

bcf = BigramCollocationFinder.from_words(words)
bcf.nbest(BigramAssocMeasures.likelihood_ratio, 10)
# Out:
# [('collectivités', 'territoriales'),
#  ("n'appelant", "d'application"),
#  ("l'union", 'européenne'),
#  ('polynésie', 'française'),
#  ("d'inscription", 'listes'),
#  ('répartition', 'sièges'),
#  ('loi', "n'appelant"),
#  ('listes', 'électorales'),
#  ('rénovant', "d'inscription"),
#  ('sièges', 'conseiller')]

# %%
filter_stops = lambda w: w in stopW or len(w) <= 3 
bcf.apply_word_filter(filter_stops)
liste = bcf.nbest(BigramAssocMeasures.likelihood_ratio, 100) #[num_f]
for item in liste:
    if "sécurité" in item:
        print(item)
#liste
# Out:
# ('sécurité', 'publique')

# %%
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import TrigramAssocMeasures

tcf = TrigramCollocationFinder.from_words(words)
tcf.apply_word_filter(filter_stops)
tcf.apply_freq_filter(3)
tcf.nbest(TrigramAssocMeasures.likelihood_ratio, 20)
# Out:
# [('général', 'collectivités', 'territoriales'),
#  ('autorités', 'administratives', 'indépendantes'),
#  ("d'inscription", 'listes', 'électorales'),
#  ('rénovant', "d'inscription", 'listes'),
#  ('répartition', 'sièges', 'conseiller')]

# %% [markdown]
# ### On peut également réaliser un moteur de recherce pour voir dans quel contexte apparaîssent les mots, avec plus de précision que les collocations ou les co-occurences

# %%
tf_vectorizer = CountVectorizer(stop_words=stopW)

# %%
def cosinus(i, j):
    num = np.dot(i, j)
    den = math.sqrt(sum(i*i))*math.sqrt(sum(j*j))
    if (den>0):    
        return (num/den)
    else:
        return 0
    
def search(q, D, n_docs):
    cc = {i: cosinus(D[i, :], q) for i in range(n_docs)}
    cc = sorted(cc.items(), key=lambda x: x[1], reverse=True)
    return cc

def askforwords(queries):
    word = input("Quels mots cherchez-vous ? :  \n")
    if word != 'n' or word != '':
        queries = queries + [w for w in nltk.tokenize.word_tokenize(word)]

    answer = input("Souhaitez vous ajouter d'autres mots ? [y/n]  \n")
    if answer == 'n':
        return(queries)
    elif answer == 'y':
        askforwords(queries)
    else:
        print("ce paramètre n'est pas correct")
    
    return(queries)

# %%
def moteur(corpus):

    tf_vectorizer.fit(corpus)
    X_hp = tf_vectorizer.transform(corpus)
    features_hp = tf_vectorizer.get_feature_names()
    X = X_hp.toarray()

    n_docs, n_terms = X.shape

    tf_sum = np.sum(X, axis=0)

    Queries = []
    Queries = askforwords(Queries)

#On créé un index, dans lequel on note la position des mots, s'il existe dans les mots du coprus

    indexes = [features_hp.index(q) for q in Queries if q in features_hp]
    print(indexes)

#On crée un tableau remplit de la longueur du nombre de mots qu'on remplit de 0, 
# avant de mettre des 1 au position des mots que l'on cherche

    query_vec = np.zeros(n_terms)
    query_vec[indexes] = 1

    result = search(query_vec, X)

    nb_top_docs = n_docs
    top_docs = [r for (r,v) in result[0:nb_top_docs] if v != 0.0]

    for i, td in zip(range(10), top_docs[0:10]):
    #    print(top_feats_in_doc(X_hp, features_hp, td))
        print("%s (%s): %s" % (i+1, td, corpus[td][0:400]), result[i][1])

# %%
moteur(SXpo.titre)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abord', 'ain', 'aren', 'assemblée', 'aujourd', 'bicaméralisme', 'bicamérisme', 'budgétaire', 'cavalier', 'confiance', 'conférence', 'conseil', 'constitutionnel', 'constitutionnelle', 'couldn', 'didn', 'doesn', 'don', 'doute', 'délégation', 'enquête', 'exposé', 'financement', 'finances', 'groupe', 'hadn', 'hasn', 'haven', 'hui', 'isn', 'jour', 'journal', 'll', 'mal', 'mdr', 'ministres', 'mixte', 'motifs', 'motion', 'nationale', 'officiel', 'ordre', 'organique', 'paritaire', 'parlementaire', 'politique', 'programme', 'proposition', 'président', 'présidents', 'publique', 'puisqu', 'question', 'ratification', 'shouldn', 'sociale', 'sommaire', 'séance', 'sécurite', 'temps', 'traités', 've', 'wasn', 'weren', 'won', 'wouldn', 'êetre'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Quels mots cherchez-vous ? :
# bla
# Souhaitez vous ajouter d'autres mots ? [y/n]
# n
# []

# %%
SXpo.iloc[163]
# Out:
# index                                  448
# preprocessed_xpo                       NaN
# titre                protection l'identité
# category                          identité
# Name: 163, dtype: object

# %% [markdown]
# ### On peut utiliser le moteur de recherche pour revoir nos catégories

# %%
test = SXpo
test
# Out:
#      index preprocessed_xpo  \
# 0        0              NaN
# 1        3              NaN
# 2        5              NaN
# 3       14              NaN
# 4       15              NaN
# ..     ...              ...
# 268    733              NaN
# 269    736              NaN
# 270    737              NaN
# 271    739              NaN
# 272    740              NaN
#
#                                                  titre      category
# 0     mesures conservatoires procédures sauvegarde ...    judiciaire
# 1     sécuriser protection sociale assistants mater...     maternels
# 2     simplification électoral transparence financi...  transparence
# 3     d'expérimentation territoriale résorber chôma...  territoriale
# 4     développement l'alternance sécurisation parco...      parcours
# ..                                                 ...           ...
# 268   encadrant conditions vente distance livres ha...      modifier
# 269   l'équipement numérique établissements spectac...     numérique
# 270   moderniser outils gouvernance Fondation patri...    moderniser
# 271             diverses collectivité Saint-Barthélemy  collectivité
# 272   nomination président Commission nationale con...      contrôle
#
# [273 rows x 4 columns]

# %%
def moteur2(corpus, Queries, tmp):
    
    tf_vectorizer.fit(corpus)
    X_hp = tf_vectorizer.transform(corpus)
    features_hp = tf_vectorizer.get_feature_names()
#    if Queries in features_hp:
#        print(features_hp.index(Queries))
#    else:
#        print("nope")
    X = X_hp.toarray()

    n_docs, n_terms = X.shape

    tf_sum = np.sum(X, axis=0)

#On créé un index, dans lequel on note la position des mots, s'il existe dans les mots du coprus

    indexes = [features_hp.index(Queries)]
#    print(indexes)

#On crée un tableau remplit de la longueur du nombre de mots qu'on remplit de 0, 
# avant de mettre des 1 au position des mots que l'on cherche

    query_vec = np.zeros(n_terms)
    query_vec[indexes] = 1

    result = search(query_vec, X, n_docs)

    nb_top_docs = n_docs
    top_docs = [r for (r,v) in result[0:nb_top_docs] if v != 0.0]

    for i, td in zip(range(10), top_docs[0:10]):
    #    print(top_feats_in_doc(X_hp, features_hp, td))
        tmp["Category"].iloc[td].append([Queries, result[i][1]])
    return(tmp)

# %%
tmp = pd.DataFrame()
tmp['Category'] = [[] for i in range(len(test.titre))]

print(type(test.titre))

for word in cloud_labels:
#    print(word)
    tmp = moteur2(test.titre, word, tmp)

tmp
# Out:
# <class 'pandas.core.series.Series'>
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abord', 'ain', 'aren', 'assemblée', 'aujourd', 'bicaméralisme', 'bicamérisme', 'budgétaire', 'cavalier', 'confiance', 'conférence', 'conseil', 'constitutionnel', 'constitutionnelle', 'couldn', 'didn', 'doesn', 'don', 'doute', 'délégation', 'enquête', 'exposé', 'financement', 'finances', 'groupe', 'hadn', 'hasn', 'haven', 'hui', 'isn', 'jour', 'journal', 'll', 'mal', 'mdr', 'ministres', 'mixte', 'motifs', 'motion', 'nationale', 'officiel', 'ordre', 'organique', 'paritaire', 'parlementaire', 'politique', 'programme', 'proposition', 'président', 'présidents', 'publique', 'puisqu', 'question', 'ratification', 'shouldn', 'sociale', 'sommaire', 'séance', 'sécurite', 'temps', 'traités', 've', 'wasn', 'weren', 'won', 'wouldn', 'êetre'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
#                                               Category
# 0    [[biens, 0.2886751345948129], [conservatoires,...
# 1    [[assistants, 0.35355339059327373], [employeur...
# 2    [[financière, 0.4082482904638631], [politique,...
# 3    [[chômage, 0.4082482904638631], [durée, 0.4082...
# 4    [[alternance, 0.4472135954999579], [développem...
# ..                                                 ...
# 268  [[conditions, 0.2773500981126146], [contrat, 0...
# 269  [[cinématographiques, 0.4472135954999579], [nu...
# 270  [[fondation, 0.4472135954999579], [gouvernance...
# 271  [[barthélemy, 0.5], [collectivité, 0.5], [dive...
# 272  [[contrôle, 0.4082482904638631], [nationale, 0...
#
# [273 rows x 1 columns]

# %%
#for i in range(len(test)):
#    print(tmp.loc[i], test.titre.loc[i], '\n')

# %%
test.category = ["" for i in range(len(test))]
temp = tmp


for i in range(len(test)):
    item = temp.Category.iloc[i]
#    print(item)
    if len(item) == 1:
        test.category.iloc[i] = item[0][0]
        print("ive been there {}".format(i))
    elif len(item) > 1:
        j = 1
        sub = []
        lenght = len(item)
        while j < lenght:
            sub = item[j][1]
            if item[0][1] > sub:
                j+=1
            elif item[0][1] < sub:
                tempo = item[0][1]
                print(tempo, sub)
                item[0][1] = sub
                item[j][1] = tempo
                j+=1
            else:
                if item[0][0] in tf.feature and sub not in tf.feature:
                    j+=1
                elif item[0][0] not in tf.feature and sub in tf.feature:
                    tempo = item[0][1]
                    print(tempo, sub)
                    item[0][1] = sub
                    item[j][1] = tempo
                    j+=1
                else:
                    j+=1
        test.category.iloc[i] = item[0][0]
        print("ive been there 2 {} : {} / {}".format(i, len(item), j))
        print(item[0][1])
        print(item[1][1])
#        print(test.category.iloc[i])
    print("ive been here {}".format(i))
test.category
# Out:
# 0.2886751345948129 0.5773502691896258
# ive been there 2 0 : 9 / 9
# 0.5773502691896258
# 0.2886751345948129
# ive been here 0
# ive been there 2 1 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 1
# ive been there 2 2 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 2
# ive been there 2 3 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 3
# ive been there 2 4 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 4
# ive been there 2 5 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 5
# ive been there 2 6 : 4 / 4
# 0.5
# 0.5
# ive been here 6
# 0.20412414523193154 0.4082482904638631
# ive been there 2 7 : 15 / 15
# 0.4082482904638631
# 0.20412414523193154
# ive been here 7
# ive been there 2 8 : 8 / 8
# 0.3333333333333333
# 0.3333333333333333
# ive been here 8
# ive been there 2 9 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 9
# ive been there 2 10 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 10
# 0.2773500981126146 0.5547001962252291
# ive been there 2 11 : 10 / 10
# 0.5547001962252291
# 0.2773500981126146
# ive been here 11
# ive been there 2 12 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 12
# ive been there 2 13 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 13
# ive been there 2 14 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 14
# ive been there 15
# ive been here 15
# ive been there 2 16 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 16
# ive been there 2 17 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 17
# ive been there 2 18 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 18
# 0.3333333333333333 0.6666666666666666
# ive been there 2 19 : 6 / 6
# 0.6666666666666666
# 0.3333333333333333
# ive been here 19
# ive been there 2 20 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 20
# ive been there 2 21 : 4 / 4
# 0.5
# 0.5
# ive been here 21
# ive been there 2 22 : 4 / 4
# 0.5
# 0.5
# ive been here 22
# ive been there 2 23 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 23
# 0.23570226039551587 0.47140452079103173
# ive been there 2 24 : 15 / 15
# 0.47140452079103173
# 0.23570226039551587
# ive been here 24
# ive been there 2 25 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 25
# ive been there 2 26 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 26
# ive been there 2 27 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 27
# ive been there 2 28 : 11 / 11
# 0.30151134457776363
# 0.30151134457776363
# ive been here 28
# ive been there 2 29 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 29
# 0.31622776601683794 0.6324555320336759
# ive been there 2 30 : 7 / 7
# 0.6324555320336759
# 0.31622776601683794
# ive been here 30
# ive been there 2 31 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 31
# ive been there 2 32 : 4 / 4
# 0.5
# 0.5
# ive been here 32
# ive been there 2 33 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 33
# ive been there 2 34 : 4 / 4
# 0.5
# 0.5
# ive been here 34
# ive been there 2 35 : 13 / 13
# 0.2773500981126146
# 0.2773500981126146
# ive been here 35
# ive been there 2 36 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 36
# ive been there 2 37 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 37
# ive been there 2 38 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 38
# 0.2672612419124244 0.5345224838248488
# ive been there 2 39 : 11 / 11
# 0.5345224838248488
# 0.2672612419124244
# ive been here 39
# ive been there 2 40 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 40
# ive been there 2 41 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 41
# ive been there 2 42 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 42
# ive been there 2 43 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 43
# ive been there 2 44 : 4 / 4
# 0.5
# 0.5
# ive been here 44
# ive been there 2 45 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 45
# ive been there 2 46 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 46
# ive been there 2 47 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 47
# 0.30151134457776363 0.6030226891555273
# ive been there 2 48 : 8 / 8
# 0.6030226891555273
# 0.30151134457776363
# ive been here 48
# ive been there 2 49 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 49
# ive been there 2 50 : 12 / 12
# 0.2886751345948129
# 0.2886751345948129
# ive been here 50
# ive been there 2 51 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 51
# ive been there 2 52 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 52
# ive been there 2 53 : 4 / 4
# 0.5
# 0.5
# ive been here 53
# ive been there 2 54 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 54
# ive been there 2 55 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 55
# ive been there 2 56 : 4 / 4
# 0.5
# 0.5
# ive been here 56
# ive been there 2 57 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 57
# 0.2773500981126146 0.5547001962252291
# ive been there 2 58 : 9 / 9
# 0.5547001962252291
# 0.2773500981126146
# ive been here 58
# ive been there 2 59 : 4 / 4
# 0.5
# 0.5
# ive been here 59
# ive been there 2 60 : 17 / 17
# 0.24253562503633297
# 0.24253562503633297
# ive been here 60
# ive been there 2 61 : 4 / 4
# 0.5
# 0.5
# ive been here 61
# ive been there 2 62 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 62
# ive been there 2 63 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 63
# ive been there 2 64 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 64
# ive been there 2 65 : 4 / 4
# 0.5
# 0.5
# ive been here 65
# ive been there 2 66 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 66
# ive been there 2 67 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 67
# ive been there 2 68 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 68
# ive been there 2 69 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 69
# ive been there 2 70 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 70
# ive been there 2 71 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 71
# ive been there 2 72 : 4 / 4
# 0.5
# 0.5
# ive been here 72
# ive been there 2 73 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 73
# ive been there 2 74 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 74
# ive been there 2 75 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 75
# ive been there 2 76 : 14 / 14
# 0.2672612419124244
# 0.2672612419124244
# ive been here 76
# ive been there 2 77 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 77
# ive been there 2 78 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 78
# ive been there 2 79 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 79
# ive been there 2 80 : 4 / 4
# 0.5
# 0.5
# ive been here 80
# ive been there 2 81 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 81
# ive been there 2 82 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 82
# ive been there 2 83 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 83
# ive been there 2 84 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 84
# ive been there 2 85 : 4 / 4
# 0.5
# 0.5
# ive been here 85
# ive been there 2 86 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 86
# ive been there 2 87 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 87
# ive been there 2 88 : 4 / 4
# 0.5
# 0.5
# ive been here 88
# ive been there 2 89 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 89
# ive been there 2 90 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 90
# ive been there 2 91 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 91
# ive been there 2 92 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 92
# ive been there 2 93 : 4 / 4
# 0.5
# 0.5
# ive been here 93
# ive been there 2 94 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 94
# ive been there 2 95 : 7 / 7
# 0.3333333333333333
# 0.3333333333333333
# ive been here 95
# ive been there 2 96 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 96
# ive been there 2 97 : 11 / 11
# 0.30151134457776363
# 0.30151134457776363
# ive been here 97
# ive been there 2 98 : 7 / 7
# 0.35355339059327373
# 0.35355339059327373
# ive been here 98
# ive been there 2 99 : 4 / 4
# 0.5
# 0.5
# ive been here 99
# ive been there 2 100 : 14 / 14
# 0.2672612419124244
# 0.2672612419124244
# ive been here 100
# ive been there 2 101 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 101
# ive been there 2 102 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 102
# ive been there 2 103 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 103
# ive been there 2 104 : 4 / 4
# 0.5
# 0.5
# ive been here 104
# ive been there 2 105 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 105
# ive been there 2 106 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 106
# ive been there 2 107 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 107
# ive been there 2 108 : 4 / 4
# 0.5
# 0.5
# ive been here 108
# ive been there 2 109 : 4 / 4
# 0.5
# 0.5
# ive been here 109
# ive been there 2 110 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 110
# ive been there 2 111 : 4 / 4
# 0.6324555320336759
# 0.31622776601683794
# ive been here 111
# ive been there 2 112 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 112
# ive been there 2 113 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 113
# ive been there 2 114 : 15 / 15
# 0.2581988897471611
# 0.2581988897471611
# ive been here 114
# ive been there 2 115 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 115
# ive been there 2 116 : 12 / 12
# 0.2886751345948129
# 0.2886751345948129
# ive been here 116
# ive been there 2 117 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 117
# ive been there 2 118 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 118
# ive been there 2 119 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 119
# ive been there 2 120 : 11 / 11
# 0.30151134457776363
# 0.30151134457776363
# ive been here 120
# ive been there 2 121 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 121
# ive been there 2 122 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 122
# ive been there 2 123 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 123
# ive been there 2 124 : 4 / 4
# 0.5
# 0.5
# ive been here 124
# ive been there 2 125 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 125
# ive been there 2 126 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 126
# ive been there 2 127 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 127
# ive been there 2 128 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 128
# ive been there 2 129 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 129
# ive been there 2 130 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 130
# ive been there 2 131 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 131
# ive been there 2 132 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 132
# ive been there 2 133 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 133
# ive been there 2 134 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 134
# ive been there 2 135 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 135
# ive been there 2 136 : 4 / 4
# 0.5
# 0.5
# ive been here 136
# 0.24253562503633297 0.48507125007266594
# ive been there 2 137 : 14 / 14
# 0.48507125007266594
# 0.24253562503633297
# ive been here 137
# ive been there 2 138 : 10 / 10
# 0.5547001962252291
# 0.2773500981126146
# ive been here 138
# ive been there 2 139 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 139
# ive been there 2 140 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 140
# ive been there 2 141 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 141
# ive been there 2 142 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 142
# ive been there 2 143 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 143
# ive been there 2 144 : 15 / 15
# 0.2581988897471611
# 0.2581988897471611
# ive been here 144
# ive been there 2 145 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 145
# ive been there 2 146 : 7 / 7
# 0.35355339059327373
# 0.35355339059327373
# ive been here 146
# ive been there 2 147 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 147
# ive been there 2 148 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 148
# ive been there 2 149 : 4 / 4
# 0.5
# 0.5
# ive been here 149
# ive been there 2 150 : 4 / 4
# 0.5
# 0.5
# ive been here 150
# ive been there 2 151 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 151
# ive been there 2 152 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 152
# ive been there 2 153 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 153
# ive been there 2 154 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 154
# ive been there 2 155 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 155
# ive been there 2 156 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 156
# ive been there 2 157 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 157
# ive been there 2 158 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 158
# ive been there 2 159 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 159
# ive been there 2 160 : 4 / 4
# 0.5
# 0.5
# ive been here 160
# 0.2886751345948129 0.5773502691896258
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# ive been there 2 161 : 9 / 9
# 0.5773502691896258
# 0.2886751345948129
# ive been here 161
# ive been there 2 162 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 162
# ive been there 2 163 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 163
# ive been there 2 164 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 164
# ive been there 2 165 : 11 / 11
# 0.30151134457776363
# 0.30151134457776363
# ive been here 165
# ive been there 2 166 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 166
# ive been there 2 167 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 167
# ive been there 2 168 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 168
# ive been there 2 169 : 4 / 4
# 0.5
# 0.5
# ive been here 169
# ive been there 2 170 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 170
# ive been there 2 171 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 171
# ive been there 2 172 : 21 / 21
# 0.2182178902359924
# 0.2182178902359924
# ive been here 172
# ive been there 2 173 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 173
# ive been there 2 174 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 174
# ive been there 2 175 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 175
# ive been there 2 176 : 14 / 14
# 0.2672612419124244
# 0.2672612419124244
# ive been here 176
# ive been there 2 177 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 177
# ive been there 2 178 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 178
# ive been there 2 179 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 179
# ive been there 2 180 : 4 / 4
# 0.5
# 0.5
# ive been here 180
# ive been there 2 181 : 4 / 4
# 0.5
# 0.5
# ive been here 181
# ive been there 2 182 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 182
# ive been there 2 183 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 183
# ive been there 2 184 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 184
# ive been there 2 185 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 185
# 0.2886751345948129 0.5773502691896258
# ive been there 2 186 : 9 / 9
# 0.5773502691896258
# 0.2886751345948129
# ive been here 186
# ive been there 2 187 : 4 / 4
# 0.6030226891555273
# 0.30151134457776363
# ive been here 187
# ive been there 2 188 : 4 / 4
# 0.5
# 0.5
# ive been here 188
# ive been there 2 189 : 4 / 4
# 0.5
# 0.5
# ive been here 189
# ive been there 2 190 : 4 / 4
# 0.5
# 0.5
# ive been here 190
# ive been there 2 191 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 191
# ive been there 2 192 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 192
# ive been there 2 193 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 193
# ive been there 2 194 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 194
# ive been there 2 195 : 4 / 4
# 0.5
# 0.5
# ive been here 195
# ive been there 2 196 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 196
# ive been there 2 197 : 12 / 12
# 0.2886751345948129
# 0.2886751345948129
# ive been here 197
# ive been there 2 198 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 198
# 0.30151134457776363 0.6030226891555273
# ive been there 2 199 : 8 / 8
# 0.6030226891555273
# 0.30151134457776363
# ive been here 199
# ive been there 2 200 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 200
# ive been there 2 201 : 4 / 4
# 0.5
# 0.5
# ive been here 201
# ive been there 2 202 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 202
# ive been there 2 203 : 4 / 4
# 0.5
# 0.5
# ive been here 203
# ive been there 2 204 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 204
# ive been there 2 205 : 14 / 14
# 0.2672612419124244
# 0.2672612419124244
# ive been here 205
# ive been there 2 206 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 206
# ive been there 2 207 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 207
# ive been there 2 208 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 208
# ive been there 2 209 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 209
# ive been there 2 210 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 210
# ive been there 2 211 : 10 / 10
# 0.30151134457776363
# 0.30151134457776363
# ive been here 211
# ive been there 2 212 : 4 / 4
# 0.5
# 0.5
# ive been here 212
# 0.3333333333333333 0.6666666666666666
# ive been there 2 213 : 6 / 6
# 0.6666666666666666
# 0.3333333333333333
# ive been here 213
# ive been there 2 214 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 214
# ive been there 2 215 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 215
# ive been there 2 216 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 216
# 0.2886751345948129 0.5773502691896258
# ive been there 2 217 : 8 / 8
# 0.5773502691896258
# 0.2886751345948129
# ive been here 217
# 0.2886751345948129 0.5773502691896258
# ive been there 2 218 : 6 / 6
# 0.5773502691896258
# 0.2886751345948129
# ive been here 218
# ive been there 2 219 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 219
# ive been there 2 220 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 220
# ive been there 2 221 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 221
# ive been there 2 222 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 222
# ive been there 2 223 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 223
# ive been there 2 224 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 224
# ive been there 2 225 : 11 / 11
# 0.30151134457776363
# 0.30151134457776363
# ive been here 225
# ive been there 2 226 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 226
# ive been there 2 227 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 227
# ive been there 2 228 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 228
# ive been there 2 229 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 229
# ive been there 2 230 : 12 / 12
# 0.47140452079103173
# 0.23570226039551587
# ive been here 230
# ive been there 2 231 : 4 / 4
# 0.5
# 0.5
# ive been here 231
# ive been there 2 232 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 232
# ive been there 2 233 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 233
# 0.2886751345948129 0.5773502691896258
# ive been there 2 234 : 9 / 9
# 0.5773502691896258
# 0.2886751345948129
# ive been here 234
# ive been there 2 235 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 235
# ive been there 2 236 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 236
# ive been there 2 237 : 4 / 4
# 0.5
# 0.5
# ive been here 237
# ive been there 2 238 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 238
# ive been there 2 239 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 239
# ive been there 2 240 : 4 / 4
# 0.5
# 0.5
# ive been here 240
# ive been there 2 241 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 241
# ive been there 2 242 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 242
# ive been there 2 243 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 243
# ive been there 2 244 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 244
# ive been there 2 245 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 245
# ive been there 2 246 : 4 / 4
# 0.5
# 0.5
# ive been here 246
# 0.2886751345948129 0.5773502691896258
# ive been there 2 247 : 9 / 9
# 0.5773502691896258
# 0.2886751345948129
# ive been here 247
# ive been there 2 248 : 9 / 9
# 0.3333333333333333
# 0.3333333333333333
# ive been here 248
# 0.2581988897471611 0.5163977794943222
# ive been there 2 249 : 12 / 12
# 0.5163977794943222
# 0.2581988897471611
# ive been here 249
# ive been there 2 250 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 250
# ive been there 2 251 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 251
# ive been there 2 252 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 252
# ive been there 2 253 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 253
# ive been there 2 254 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 254
# 0.31622776601683794 0.6324555320336759
# ive been there 2 255 : 4 / 4
# 0.6324555320336759
# 0.31622776601683794
# ive been here 255
# ive been there 2 256 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 256
# ive been there 2 257 : 14 / 14
# 0.2672612419124244
# 0.2672612419124244
# ive been here 257
# ive been there 2 258 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 258
# ive been there 2 259 : 3 / 3
# 0.5773502691896258
# 0.5773502691896258
# ive been here 259
# ive been there 2 260 : 4 / 4
# 0.5
# 0.5
# ive been here 260
# ive been there 2 261 : 8 / 8
# 0.35355339059327373
# 0.35355339059327373
# ive been here 261
# ive been there 2 262 : 10 / 10
# 0.31622776601683794
# 0.31622776601683794
# ive been here 262
# ive been there 2 263 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 263
# ive been there 2 264 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 264
# ive been there 2 265 : 2 / 2
# 0.7071067811865475
# 0.7071067811865475
# ive been here 265
# 0.31622776601683794 0.6324555320336759
# ive been there 2 266 : 7 / 7
# 0.6324555320336759
# 0.31622776601683794
# ive been here 266
# ive been there 2 267 : 7 / 7
# 0.3779644730092272
# 0.3779644730092272
# ive been here 267
# ive been there 2 268 : 13 / 13
# 0.2773500981126146
# 0.2773500981126146
# ive been here 268
# ive been there 2 269 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 269
# ive been there 2 270 : 5 / 5
# 0.4472135954999579
# 0.4472135954999579
# ive been here 270
# ive been there 2 271 : 4 / 4
# 0.5
# 0.5
# ive been here 271
# ive been there 2 272 : 6 / 6
# 0.4082482904638631
# 0.4082482904638631
# ive been here 272
# 0                   biens
# 1              assistants
# 2              financière
# 3                 chômage
# 4              alternance
#               ...
# 268            conditions
# 269    cinématographiques
# 270             fondation
# 271            barthélemy
# 272              contrôle
# Name: category, Length: 273, dtype: object

# %%
tab = test.category.value_counts()
tab.loc[tab>1].plot(kind="barh", figsize=(10, 8))
test
# Out:
#      index preprocessed_xpo  \
# 0        0              NaN
# 1        3              NaN
# 2        5              NaN
# 3       14              NaN
# 4       15              NaN
# ..     ...              ...
# 268    733              NaN
# 269    736              NaN
# 270    737              NaN
# 271    739              NaN
# 272    740              NaN
#
#                                                  titre            category
# 0     mesures conservatoires procédures sauvegarde ...               biens
# 1     sécuriser protection sociale assistants mater...          assistants
# 2     simplification électoral transparence financi...          financière
# 3     d'expérimentation territoriale résorber chôma...             chômage
# 4     développement l'alternance sécurisation parco...          alternance
# ..                                                 ...                 ...
# 268   encadrant conditions vente distance livres ha...          conditions
# 269   l'équipement numérique établissements spectac...  cinématographiques
# 270   moderniser outils gouvernance Fondation patri...           fondation
# 271             diverses collectivité Saint-Barthélemy          barthélemy
# 272   nomination président Commission nationale con...            contrôle
#
# [273 rows x 4 columns]

# %%
nlp = stanza.Pipeline('fr')
# Out:
# 2021-12-13 09:27:34 INFO: Loading these models for language: fr (French):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | gsd     |
# | lemma     | gsd     |
# | depparse  | gsd     |
# | ner       | wikiner |
# =======================
#
# 2021-12-13 09:27:34 INFO: Use device: cpu
# 2021-12-13 09:27:34 INFO: Loading: tokenize
# 2021-12-13 09:27:34 INFO: Loading: mwt
# 2021-12-13 09:27:34 INFO: Loading: pos
# 2021-12-13 09:27:34 INFO: Loading: lemma
# 2021-12-13 09:27:34 INFO: Loading: depparse
# 2021-12-13 09:27:36 INFO: Loading: ner
# 2021-12-13 09:27:38 INFO: Done loading processors!

# %%
for i in range(len(test)):
    temp = test.category.loc[i]
    temp = nlp(temp) 
    print(temp)
    temp = [word.lemma for sent in temp.sentences for word in sent.words if word.upos != "VERB" 
            and word.upos != "PRON"]
    test.category.loc[i] = temp

test.category
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "biens",
#       "lemma": "bien",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assistants",
#       "lemma": "assistant",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# [
#   [
#     {
#       "id": 1,
#       "text": "financière",
#       "lemma": "financier",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "chômage",
#       "lemma": "chômage",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "alternance",
#       "lemma": "alternance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "blanc",
#       "lemma": "blanc",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "gouvernance",
#       "lemma": "gouvernance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "applicable",
#       "lemma": "applicable",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "certaines",
#       "lemma": "certain",
#       "upos": "PRON",
#       "feats": "Gender=Fem|Number=Plur|Person=3|PronType=Ind",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "engagement",
#       "lemma": "engagement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "commissions",
#       "lemma": "commission",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "améliorer",
#       "lemma": "améliorer",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "création",
#       "lemma": "création",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "don",
#       "lemma": "don",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 3,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "certificats",
#       "lemma": "certificat",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "finances",
#       "lemma": "finance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assainissement",
#       "lemma": "assainissement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accord",
#       "lemma": "accord",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accompagnement",
#       "lemma": "accompagnement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agences",
#       "lemma": "agence",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "danger",
#       "lemma": "danger",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "inscription",
#       "lemma": "inscription",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "armées",
#       "lemma": "armée",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "autoriser",
#       "lemma": "autoriser",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "adapter",
#       "lemma": "adapter",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accompagner",
#       "lemma": "accompagner",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "absentéisme",
#       "lemma": "absentéisme",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "armes",
#       "lemma": "arme",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assurance",
#       "lemma": "assurance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "affaires",
#       "lemma": "affaire",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "deuxième",
#       "lemma": "deuxième",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "dématérialisation",
#       "lemma": "dématérialisation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 17,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "autorisant",
#       "lemma": "autoriser",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accès",
#       "lemma": "accès",
#       "upos": "NOUN",
#       "feats": "Gender=Masc",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agent",
#       "lemma": "agent",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "aériennes",
#       "lemma": "aérien",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administrative",
#       "lemma": "administratif",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "devoir",
#       "lemma": "devoir",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accaparement",
#       "lemma": "accaparement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accéder",
#       "lemma": "accéder",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "civile",
#       "lemma": "civil",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "amélioration",
#       "lemma": "amélioration",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "aquatiques",
#       "lemma": "aquatique",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "diplômés",
#       "lemma": "diplômé",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "distribution",
#       "lemma": "distribution",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "commerciale",
#       "lemma": "commercial",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assainissement",
#       "lemma": "assainissement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "faciliter",
#       "lemma": "faciliter",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "couples",
#       "lemma": "couple",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "acceptation",
#       "lemma": "acceptation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "aidants",
#       "lemma": "aidant",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assurance",
#       "lemma": "assurance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "fracture",
#       "lemma": "fracture",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "applicables",
#       "lemma": "applicable",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "clarifier",
#       "lemma": "clarifier",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "année",
#       "lemma": "année",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "instauration",
#       "lemma": "instauration",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "biologie",
#       "lemma": "biologie",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "départements",
#       "lemma": "département",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "interdiction",
#       "lemma": "interdiction",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "abroger",
#       "lemma": "abroger",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "dignité",
#       "lemma": "dignité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "médecine",
#       "lemma": "médecine",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assemblée",
#       "lemma": "assemblée",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "alimentaire",
#       "lemma": "alimentaire",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "lutte",
#       "lemma": "lutte",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "actionnariat",
#       "lemma": "actionnariat",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "dialogue",
#       "lemma": "dialogue",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "journée",
#       "lemma": "journée",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assurance",
#       "lemma": "assurance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administration",
#       "lemma": "administration",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "information",
#       "lemma": "information",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "développement",
#       "lemma": "développement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 13,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accompagnement",
#       "lemma": "accompagnement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "appels",
#       "lemma": "appel",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "amélioration",
#       "lemma": "amélioration",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administratifs",
#       "lemma": "administratif",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agence",
#       "lemma": "agence",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "championnat",
#       "lemma": "championnat",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "reconquérir",
#       "lemma": "reconquérir",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "hune",
#       "lemma": "hune",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "complémentaire",
#       "lemma": "complémentaire",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "alimentation",
#       "lemma": "alimentation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "campagnes",
#       "lemma": "campagne",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "commerciale",
#       "lemma": "commercial",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "diverses",
#       "lemma": "divers",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "bleue",
#       "lemma": "bleu",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "gaz",
#       "lemma": "gaz",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 3,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "prévention",
#       "lemma": "prévention",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "condamnation",
#       "lemma": "condamnation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "certains",
#       "lemma": "certain",
#       "upos": "PRON",
#       "feats": "Gender=Masc|Number=Plur|Person=3|PronType=Ind",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "prescription",
#       "lemma": "prescription",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "amélioration",
#       "lemma": "amélioration",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administratives",
#       "lemma": "administratif",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 15,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "autorités",
#       "lemma": "autorité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "chargées",
#       "lemma": "charger",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Plur|Tense=Past|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "alimentaire",
#       "lemma": "alimentaire",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "activité",
#       "lemma": "activité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "activités",
#       "lemma": "activité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "enseignants",
#       "lemma": "enseignant",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "algérie",
#       "lemma": "algérie",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "conseillers",
#       "lemma": "conseiller",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "attractions",
#       "lemma": "attraction",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administrative",
#       "lemma": "administratif",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "exercice",
#       "lemma": "exercice",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "applicables",
#       "lemma": "applicable",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "alerte",
#       "lemma": "alerte",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "culture",
#       "lemma": "culture",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "aidants",
#       "lemma": "aidant",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "renforcer",
#       "lemma": "renforcer",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "abrogation",
#       "lemma": "abrogation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "pompiers",
#       "lemma": "pompier",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "langues",
#       "lemma": "langue",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "autorisant",
#       "lemma": "autoriser",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "activité",
#       "lemma": "activité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agricoles",
#       "lemma": "agricole",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "actes",
#       "lemma": "acte",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "encadrer",
#       "lemma": "encadrer",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "améliorant",
#       "lemma": "améliorer",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "détecteurs",
#       "lemma": "détecteur",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "caractère",
#       "lemma": "caractère",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agricoles",
#       "lemma": "agricole",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "abus",
#       "lemma": "abus",
#       "upos": "NOUN",
#       "feats": "Gender=Masc",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "barthélemy",
#       "lemma": "barthélemy",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "actualisation",
#       "lemma": "actualisation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 13,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "créant",
#       "lemma": "créer",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "appelant",
#       "lemma": "appeler",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "civiles",
#       "lemma": "civil",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "exploitation",
#       "lemma": "exploitation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assouplir",
#       "lemma": "assouplir",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "enchères",
#       "lemma": "enchère",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "clarifier",
#       "lemma": "clarifier",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agence",
#       "lemma": "agence",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agricoles",
#       "lemma": "agricole",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "contrat",
#       "lemma": "contrat",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "crimes",
#       "lemma": "crime",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "globale",
#       "lemma": "global",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "collectivités",
#       "lemma": "collectivité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 13,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agglomération",
#       "lemma": "agglomération",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 13,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "encadrement",
#       "lemma": "encadrement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "indépendance",
#       "lemma": "indépendance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "améliorer",
#       "lemma": "améliorer",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "livre",
#       "lemma": "livre",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "clarifier",
#       "lemma": "clarifier",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "chirurgien",
#       "lemma": "chirurgien",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "diverses",
#       "lemma": "divers",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "application",
#       "lemma": "application",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "adaptation",
#       "lemma": "adaptation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "aménagement",
#       "lemma": "aménagement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "concurrence",
#       "lemma": "concurrence",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "domicile",
#       "lemma": "domicile",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "communes",
#       "lemma": "commune",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "française",
#       "lemma": "français",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "amélioration",
#       "lemma": "amélioration",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "civils",
#       "lemma": "civil",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "clercs",
#       "lemma": "clerc",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "candidats",
#       "lemma": "candidat",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "façon",
#       "lemma": "façon",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agglomération",
#       "lemma": "agglomération",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 13,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "certaines",
#       "lemma": "certain",
#       "upos": "PRON",
#       "feats": "Gender=Fem|Number=Plur|Person=3|PronType=Ind",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "chauffeur",
#       "lemma": "chauffeur",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "actes",
#       "lemma": "acte",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accès",
#       "lemma": "accès",
#       "upos": "NOUN",
#       "feats": "Gender=Masc",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "identité",
#       "lemma": "identité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "chantier",
#       "lemma": "chantier",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "affichée",
#       "lemma": "afficher",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "calendrier",
#       "lemma": "calendrier",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "application",
#       "lemma": "application",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "enfant",
#       "lemma": "enfant",
#       "upos": "NOUN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agir",
#       "lemma": "agir",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "france",
#       "lemma": "france",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "information",
#       "lemma": "information",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "agences",
#       "lemma": "agence",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "communications",
#       "lemma": "communication",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "adaptation",
#       "lemma": "adaptation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "alerte",
#       "lemma": "alerte",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "activités",
#       "lemma": "activité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "accueil",
#       "lemma": "accueil",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "améliorer",
#       "lemma": "améliorer",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "européenne",
#       "lemma": "européen",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "aléatoire",
#       "lemma": "aléatoire",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "allègement",
#       "lemma": "allègement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "azote",
#       "lemma": "azote",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "finances",
#       "lemma": "finance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
# ...
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "carte",
#       "lemma": "carte",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "discrimination",
#       "lemma": "discrimination",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "dirigeants",
#       "lemma": "dirigeant",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "particulier",
#       "lemma": "particulier",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "aérien",
#       "lemma": "aérien",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administratives",
#       "lemma": "administratif",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 15,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "cynégétique",
#       "lemma": "cynégétique",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "conseiller",
#       "lemma": "conseiller",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "certains",
#       "lemma": "certain",
#       "upos": "PRON",
#       "feats": "Gender=Masc|Number=Plur|Person=3|PronType=Ind",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "applicables",
#       "lemma": "applicable",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "abroger",
#       "lemma": "abroger",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "forêts",
#       "lemma": "forêt",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "acte",
#       "lemma": "acte",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administration",
#       "lemma": "administration",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "citoyen",
#       "lemma": "citoyen",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "améliorer",
#       "lemma": "améliorer",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assemblée",
#       "lemma": "assemblée",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "activité",
#       "lemma": "activité",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "abroger",
#       "lemma": "abroger",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "médiateur",
#       "lemma": "médiateur",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "concertation",
#       "lemma": "concertation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "appelant",
#       "lemma": "appeler",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "calédonie",
#       "lemma": "calédonie",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "défense",
#       "lemma": "défense",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "caisse",
#       "lemma": "caisse",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "action",
#       "lemma": "action",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "garantir",
#       "lemma": "garantir",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "associatif",
#       "lemma": "associatif",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "civique",
#       "lemma": "civique",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "art",
#       "lemma": "art",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 3,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "dématérialisation",
#       "lemma": "dématérialisation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 17,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "action",
#       "lemma": "action",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 6,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "déploiement",
#       "lemma": "déploiement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "confiscation",
#       "lemma": "confiscation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assemblée",
#       "lemma": "assemblée",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "croix",
#       "lemma": "croix",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "application",
#       "lemma": "application",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "base",
#       "lemma": "base",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assainissement",
#       "lemma": "assainissement",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 14,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "cardiaque",
#       "lemma": "cardiaque",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "délit",
#       "lemma": "délit",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administratives",
#       "lemma": "administratif",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 15,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "administratives",
#       "lemma": "administratif",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 15,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "bonus",
#       "lemma": "bonus",
#       "upos": "NOUN",
#       "feats": "Gender=Masc",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 5,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "commises",
#       "lemma": "commettre",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Plur|Tense=Past|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "juridictions",
#       "lemma": "juridiction",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 12,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "alimentaire",
#       "lemma": "alimentaire",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "conjugales",
#       "lemma": "conjugal",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "auteurs",
#       "lemma": "auteur",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 7,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "certaines",
#       "lemma": "certain",
#       "upos": "PRON",
#       "feats": "Gender=Fem|Number=Plur|Person=3|PronType=Ind",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "améliorant",
#       "lemma": "améliorer",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "concernés",
#       "lemma": "concerner",
#       "upos": "VERB",
#       "feats": "Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "funéraire",
#       "lemma": "funéraire",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "assurance",
#       "lemma": "assurance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "abritant",
#       "lemma": "abriter",
#       "upos": "VERB",
#       "feats": "Tense=Pres|VerbForm=Part",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "conditions",
#       "lemma": "condition",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "cinématographiques",
#       "lemma": "cinématographique",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 18,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "fondation",
#       "lemma": "fondation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 9,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "barthélemy",
#       "lemma": "barthélemy",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 10,
#       "ner": "O"
#     }
#   ]
# ]
# [
#   [
#     {
#       "id": 1,
#       "text": "contrôle",
#       "lemma": "contrôle",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 8,
#       "ner": "O"
#     }
#   ]
# ]
# 0                   [bien]
# 1              [assistant]
# 2              [financier]
# 3                [chômage]
# 4             [alternance]
#               ...
# 268            [condition]
# 269    [cinématographique]
# 270            [fondation]
# 271           [barthélemy]
# 272             [contrôle]
# Name: category, Length: 273, dtype: object

# %%
tab = test.category.loc[test.category != ""].value_counts()
tab.loc[tab>1].plot(kind="barh", figsize=(10, 8))
# Out:
# <AxesSubplot:>
