# %%
import stanza
from Loading_Json import *

#nlp = stanza.Pipeline('fr')
df = pd.read_excel("export_excel.xlsx")
test = df.loc[1, "Exposé des motifs"]

# %%
doc = nlp(test)

# %%
print(doc)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "La",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "start_char": 1,
#       "end_char": 3,
#       "ner": "B-LOC"
#     },
#     {
#       "id": 2,
#       "text": "France",
#       "lemma": "France",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 4,
#       "deprel": "nsubj",
#       "start_char": 4,
#       "end_char": 10,
#       "ner": "E-LOC"
#     },
#     {
#       "id": 3,
#       "text": "a",
#       "lemma": "avoir",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "aux:tense",
#       "start_char": 11,
#       "end_char": 12,
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "signé",
#       "lemma": "signer",
#       "upos": "VERB",
# ...

# %%
print([word.lemma for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# ['le', 'France', 'avoir', 'signer', 'le', '18', 'décembre', '2008', 'à', 'Paris', 'un', 'accord', 'avec', 'le', 'agence', 'spatial', 'européen', '(', 'ci-après', 'dénommer', '«', 'ASE', '»', 'ou', '«', 'agence', '»', ')', 'relatif', 'à', 'le', 'centre', 'spatial', 'guyanais', '(', 'CSG', ')', 'et', 'à', 'le', 'prestation', 'associer', '.', 'le', 'objet', 'de', 'ce', 'accord', 'être', 'préciser', 'à', 'son', 'article', '2', '.', 'il', 'prévoir', 'le', 'modalité', 'de', 'mise', 'à', 'disposition', 'de', 'le', 'terrain', 'de', 'le', 'CSG', 'à', 'le', 'agence', 'en', 'préciser', 'le', 'relation', 'entre', 'le', 'partie', ',', 'le', 'droit', 'et', 'obligation', 'réciproque', ',', 'ainsi', 'que', 'le', 'modalité', 'selon', 'lequel', 'le', 'gouvernement', 'français', 'garantir', 'le', 'disponibilité', 'de', 'le', 'ensemble', 'de', 'soutien', 'à', 'le', 'lancement', 'de', 'le', 'CSG', 'à', 'le', 'fin', 'de', 'le', 'programme', 'de', 'le', 'ASE', 'et', 'de', 'le', 'phase', 'de', 'exploitation
# ...
